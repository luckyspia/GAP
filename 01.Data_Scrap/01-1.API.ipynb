# %% [markdown]
# ### Import Library

# %%
from bs4 import BeautifulSoup as bs
from urllib import request
import urllib
import requests
import pandas as pd
import re
import os
import sys
import json

# %% [markdown]
# ### Naver API

# %%
def Get_News(encText, sPage):
    url = 'https://openapi.naver.com/v1/search/news?query=' + encText
    url = url + "&start=" + str(sPage) + "&display=100" + "&sort=sim"
    
    headers = {"X-Naver-Client-Id":"KKp83R4CsOFadKFlvXZN",
               "X-Naver-Client-Secret":"gAqdf1x0Um"}
    
    res_content = requests.get(url, headers=headers)

    if res_content.status_code == 200:
        res_json = res_content.json()
    else:
        print("Error code:" + str(res_json.status_code))
        sys.exit(0)
        
    df = pd.DataFrame(res_json['items'])
    df = df[['title', 'description']]
    return df

# %%
encText = urllib.parse.quote("노인")
data = pd.DataFrame()

for i in range(1, 1001, 100):
    df = Get_News(encText, i)
    data = pd.concat([data, df])
    
data
# Out:
#                                             title  \
# 0              부산남고 학생들, 실종 치매 <b>노인</b> 찾아 경찰 표창
# 1   &quot;여성·아동·<b>노인</b> 전원 대피&quot;‥아조우스탈의 운명은?
# 2                      <b>노인</b>복지관 방문한 안철수 전 위원장
# 3                  안산시 <b>노인</b>무상교통 전면확대…연간 16만원
# 4   김경민 &quot;<b>노인</b>수당·장애인수당 연 100만 원 지급&quot;
# ..                                            ...
# 95   서구<b>노인</b>복지관, 어버이날 맞아 취약계층어르신 80가구 감사선물 전달
# 96  대한<b>노인</b>회 충남 계룡시지회, 그라운드골프대회 2년 연속 종합우승 쾌거
# 97                  광주남부경찰서, <b>노인</b> 교통사고 주의 당부
# 98             대한<b>노인</b>체육회 시니어보디빌딩협회 주요 임원진 선출
# 99      사투리도 알아듣는 ‘기가지니’… KT, ‘독거<b>노인</b> 돌봄’ 확대
#
#                                           description
# 0   치매 <b>노인</b>을 찾는 데 도움을 줘 경찰 표창을 받았다. 10일 부산교육청...
# 1   이곳 지하에 숨어있던 여성과 어린이, <b>노인</b>들은 모두 구조됐다고 우크라이...
# 2   김종택기자 = 경기 분당갑 국회의원 보궐선거 출마를 선언한 안철수 전 대통령직인수위...
# 3   안산시가 기초연금을 받는 만65세 이상 <b>노인</b>을 대상으로 실시하던 무상교...
# 4   <b>노인</b>수당과 장애인수당을 파격적으로 지급하겠다는 공약이 제시됐습니다. 김...
# ..                                                ...
# 95  대한불교조계종사회복지재단 서구<b>노인</b>복지관재가<b>노인</b>지원센터(관장...
# 96  대한<b>노인</b>회 충남 계룡시지회(지회장 김정수)는 5월 4일 홍성 홍주종합경...
# 97  광주남부경찰서, <b>노인</b> 대상 교통사고 주의 당부 광주 남부경찰서 교통안전...
# 98  대한<b>노인</b>체육회 시니어 보디빌딩협회는 27일, 군산지역 한 횟집에서 전국...
# 99  KT는 지난해 4월 광주광역시 서구 내 독거<b>노인</b> 100가구를 대상으로 ...
#
# [1000 rows x 2 columns]

# %%
encText = urllib.parse.quote("노인 일자리")
data_2 = pd.DataFrame()

for i in range(1, 1001, 100):
    df = Get_News(encText, i)
    data_2 = pd.concat([data_2, df])
    
data_2
# Out:
#                                                 title  \
# 0        권익현 부안군수 예비후보, “<b>노인일자리</b> 영농사업단 확대 운영” 공약
# 1   권익현 &quot;<b>노인일자리</b> 영농사업단 확대…500여 <b>일자리</b...
# 2                      “<b>노인 일자리</b> 영농사업단 확대 운영 약속”
# 3   권익현 부안군수 예비후보 &quot;<b>노인일자리</b> 영농사업단 확대 운영&q...
# 4          권익현 부안군수 예비후보, ‘<b>노인일자리</b> 영농단 확대 운영’ 공약
# ..                                                ...
# 95                   태안군, 올해 <b>노인일자리</b> 사업 3919명 참여
# 96                      태안군, <b>노인일자리</b> 사업비 139억 확보
# 97                          양승조-김태흠, 네거티브 신경전 속 공약 경쟁
# 98                  태안군, ‘올해 <b>노인일자리</b> 사업 도내 최다 편성
# 99                 태안군, <b>노인일자리</b>사업비 139억 확보 도내 최다
#
#                                           description
# 0   권익현 더불어민주당 부안군수 예비후보는 9일 어르신들의 활기찬 노후와 사회참여 기회...
# 1   권익현의 소확행공약'여덟번째 발표 권익현 더불어민주당 부안군수 예비후보는 9일 <b...
# 2   권익현 부안군수 예비후보 권익현 부안군수 예비후보 권익현 더불어민주당 부안군수 예비...
# 3   권익현 민주당 부안군수 예비후보는 9일 어르신들의 활기찬 노후와 사회참여 기회 확대...
# 4   권익현 부안군수 예비후보 권익현 더불어민주당 전북 부안군수 예비후보는 9일 ‘소확행...
# ..                                                ...
# 95  지난해 <b>노인일자리</b> 사업장(달래 수확)을 찾은 가세로 군수 충남 태안군이...
# 96  지난해 2월 원북면 마산리의 <b>노인일자리</b> 사업장(달래 수확)을 찾은 가세...
# 97  확충, <b>노인일자리</b> 확대 등 보다 포괄적인 시각으로 고령화 문제를 접근해...
# 98  충남 태안군이 올해 역대 최다인 총 139억 원의 <b>노인일자리</b> 사업비를 ...
# 99  사진은 가세로 군수가 지난해 2월 원북면 마산리의 <b>노인일자리</b> 사업장(달...
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### Word Cloud

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager

font_fname = 'C:/Windows/Fonts/malgun.ttf'
font_family = font_manager.FontProperties(fname=font_fname).get_name()
plt.rcParams["font.family"] = font_family

from konlpy.tag import Okt
from collections import Counter
from wordcloud import WordCloud as WC
from PIL import Image
import numpy as np

# %%
def make_cloud(data, keyword):
    cols = data.columns

    for col in cols:
        data[col] = data[col].str.replace(pat="[</b>]", repl='', regex=True)
        data[col] = data[col].str.replace(pat="[&quot;]", repl='', regex=True)
        data[col] = data[col].str.replace(pat="[노인]", repl='', regex=True)
        data[col] = data[col].str.replace(pat="[일자리]", repl='', regex=True)
        
    okt = Okt()

    contents = data['title']
    noun_lst = []

    for content in contents:
        noun_lst.append(okt.nouns(content))

    noun = []

    for nouns in noun_lst:
        for noun_ in nouns:
            noun.append(noun_)

    title_cnt = Counter(noun)

    title_tuple = title_cnt.most_common()

    title_rev = [(key, num) for (key, num) in title_tuple if num >= 10 and key != keyword]

    img = Image.open("./data/mask_opt.png")
    mask_arr = np.array(img)
    
    wc = WC(font_path = font_fname,background_color='white',mask=mask_arr)
    cloud = wc.generate_from_frequencies(dict(title_rev))

    plt.figure(figsize=(10, 10))
    plt.imshow(cloud)
    plt.axis('Off') # 눈금선
    plt.show()

# %%
make_cloud(data, '노인')

# %%
make_cloud(data_2, '노인 일자리')

# %% [markdown]
# ### 공공데이터 포털 API

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
from lxml import html
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus, unquote

# %%
# 노인 구인 정보
url = 'http://apis.data.go.kr/B552474/SenuriService/getJobList'
key = 'XmXenimRCP43/5wyQaiqZ0CVMO/4ulD6cUtD00z8cINrnHw7sNrEZU5okkUNM/xH9Tzx4fV21AQAIrh/Ycsotw=='

query = '?' + urlencode(
{
    quote_plus('serviceKey'):key,
    quote_plus('pageNo'):1,
    quote_plus('numOfRows'):10
})

response = requests.get(url+query).text.encode('utf-8')
xml = bs(response, 'lxml-xml')

rows = xml.findAll('item')
rows
# Out:
# [<item><acptMthd>방문</acptMthd><deadline>접수중</deadline><emplymShp>CM0105</emplymShp><emplymShpNm>CM0105</emplymShpNm><frDd>20220506</frDd><jobId>K120252205060040</jobId><oranNm>(주)드림잡</oranNm><organYn>N</organYn><recrtTitle>의정부시 해동 본 타워 시설기사모집</recrtTitle><stmId>B</stmId><stmNm>워크넷</stmNm><toDd>20220705</toDd><workPlc>010060</workPlc><workPlcNm>경기 의정부시</workPlcNm></item>,
#  <item><acptMthd>방문</acptMthd><deadline>접수중</deadline><emplymShp>CM0105</emplymShp><emplymShpNm>CM0105</emplymShpNm><frDd>20220506</frDd><jobId>K120422205060051</jobId><jobcls>A08009</jobcls><jobclsNm>기타</jobclsNm><oranNm>(주)에이치아이티에스손해사정</oranNm><organYn>N</organYn><recrtTitle>(주)에이치아이티에스손해사정 정보입력 신입/경력사원 채용</recrtTitle><stmId>B</stmId><stmNm>워크넷</stmNm><toDd>20220705</toDd><workPlc>010200</workPlc><workPlcNm>부산 동구</workPlcNm></item>,
#  <item><acptMthd>방문</acptMthd><deadline>접수중</deadline><emplymShp>CM0105</emplymShp><emplymShpNm>CM0105</emplymShpNm><frDd>20220506</frDd><jobId>K120032205060059</jobId><oranNm>(주)유니에스</oranNm><organYn>N</organYn><recrtTitle>[일산] 동국대병원 호스피스병동 사원 채용</recrtTitle><stmId>B</stmId><stmNm>워크넷</stmNm><toDd>20220705</toDd><workPlc>010010</workPlc><workPlcNm>경기 고양시 일산동구</workPlcNm></item>,
#  <item><acptMthd>방문</acptMthd><deadline>접수중</deadline><emplymShp>CM0103</emplymShp><emplymShpNm>CM0103</emplymShpNm><frDd>20220506</frDd><jobId>K120032205060061</jobId><oranNm>강남70플러스라운지</oranNm><organYn>N</organYn><recrtTitle>강남70플러스라운지 단기계약직 근로자 채용 공고</recrtTitle><stmId>B</stmId><stmNm>워크넷</stmNm><toDd>20220705</toDd><workPlc>010010</workPlc><workPlcNm>서울 강남구</workPlcNm></item>,
#  <item><acptMthd>방문</acptMthd><deadline>접수중</deadline><emplymShp>CM0105</emplymShp><emplymShpNm>CM0105</emplymShpNm><frDd>20220506</frDd><jobId>K131112205060040</jobId><jobcls>A08009</jobcls><jobclsNm>기타</jobclsNm><oranNm>(주)경남은행</oranNm><organYn>N</organYn><recrtTitle>BNK경남은행 사무행원 신규 채용 공고</recrtTitle><stmId>B</stmId><stmNm>워크넷</stmNm><toDd>20220513</toDd><workPlc>040150</workPlc><workPlcNm>경남 창원시 마산회원구</workPlcNm></item>,
#  <item><acptMthd>방문</acptMthd><deadline>접수중</deadline><emplymShp>CM0105</emplymShp><emplymShpNm>CM0105</emplymShpNm><frDd>20220506</frDd><jobId>K120422205060054</jobId><jobcls>A08009</jobcls><jobclsNm>기타</jobclsNm><oranNm>(주)에이치아이티에스손해사정</oranNm><organYn>N</organYn><recrtTitle>(주)에이치아이티에스손해사정 정보입력 신입/경력사원 채용</recrtTitle><stmId>B</stmId><stmNm>워크넷</stmNm><toDd>20220705</toDd><workPlc>010200</workPlc><workPlcNm>대구 중구</workPlcNm></item>,
#  <item><acptMthd>방문</acptMthd><deadline>접수중</deadline><emplymShp>CM0105</emplymShp><emplymShpNm>CM0105</emplymShpNm><frDd>20220506</frDd><jobId>K130232205060122</jobId><oranNm>(주)에스엠이엔지</oranNm><organYn>N</organYn><recrtTitle>[사상구] 제조 단순 종사원 채용</recrtTitle><stmId>B</stmId><stmNm>워크넷</stmNm><toDd>20220705</toDd><workPlc>090090</workPlc><workPlcNm>부산 사상구</workPlcNm></item>,
#  <item><acptMthd>방문</acptMthd><deadline>접수중</deadline><emplymShp>CM0105</emplymShp><emplymShpNm>CM0105</emplymShpNm><frDd>20220506</frDd><jobId>KJPL002205060001</jobId><oranNm>장수군노인복지관</oranNm><organYn>N</organYn><recrtTitle>장수노인복지관 생활지원사 모집</recrtTitle><stmId>B</stmId><stmNm>워크넷</stmNm><toDd>20220520</toDd><workPlc>130110</workPlc><workPlcNm>전북 장수군</workPlcNm></item>,
#  <item><acptMthd>방문</acptMthd><deadline>접수중</deadline><emplymShp>CM0103</emplymShp><emplymShpNm>CM0103</emplymShpNm><frDd>20220506</frDd><jobId>KJK3002205060010</jobId><oranNm>나라개발시스템(주)</oranNm><organYn>N</organYn><recrtTitle>힐스테이트 지제역 아파트 미화원 모집(외곽, 주차장)</recrtTitle><stmId>B</stmId><stmNm>워크넷</stmNm><toDd>20220605</toDd><workPlc>010010</workPlc><workPlcNm>경기 평택시</workPlcNm></item>,
#  <item><acptMthd>방문</acptMthd><deadline>접수중</deadline><emplymShp>CM0103</emplymShp><emplymShpNm>CM0103</emplymShpNm><frDd>20220506</frDd><jobId>K151342205060074</jobId><oranNm>새롬에스앤씨 주식회사</oranNm><organYn>N</organYn><recrtTitle>*[하남]아파트청소원(실내)모집-미사강변파밀리에(미사15단지)</recrtTitle><stmId>B</stmId><stmNm>워크넷</stmNm><toDd>20220517</toDd><workPlc>030340</workPlc><workPlcNm>경기 하남시</workPlcNm></item>]

# %%
# 노인일자리 사업 참여기관 목록 조회
url = 'http://apis.data.go.kr/B552474/OdsnJobOfferPblancService/getOdsnJobOfferPblancList'
key = 'XmXenimRCP43/5wyQaiqZ0CVMO/4ulD6cUtD00z8cINrnHw7sNrEZU5okkUNM/xH9Tzx4fV21AQAIrh/Ycsotw=='

query = '?' + urlencode(
{
    quote_plus('serviceKey'):key,
    quote_plus('pageNo'):1,
    quote_plus('numOfRows'):10,
    quote_plus('projNo'):'2012-01316',
})

response = requests.get(url+query).text.encode('utf-8')
xml = bs(response, 'lxml-xml')

xml
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <OpenAPI_ServiceResponse>
# <cmmMsgHeader>
# <errMsg>SERVICE ERROR</errMsg>
# <returnAuthMsg>HTTP_ERROR</returnAuthMsg>
# <returnReasonCode>04</returnReasonCode>
# </cmmMsgHeader>
# </OpenAPI_ServiceResponse>

# %%
# 자립형 일자리 수행기관 목록 조회
url = 'http://apis.data.go.kr/B552474/JobBsnInfoService/getJobOperInsttList'
key = 'XmXenimRCP43/5wyQaiqZ0CVMO/4ulD6cUtD00z8cINrnHw7sNrEZU5okkUNM/xH9Tzx4fV21AQAIrh/Ycsotw=='

query = '?' + urlencode(
{
    quote_plus('serviceKey'):key,
    quote_plus('pageNo'):1,
    quote_plus('numOfRows'):100,
    quote_plus('dstrCd1'):4800000000,
    quote_plus('dstrCd2'):4817000000,
    quote_plus('projNo'):2022
})

response = requests.get(url+query).text.encode('utf-8')
xml = bs(response, 'lxml-xml')

rows = xml.findAll('item')
rows
# Out:
# [<item><faxNum>******</faxNum><orgCd>0001442</orgCd><orgName>진주노인일자리창출지원센터</orgName><orgTypeNm>수행기관</orgTypeNm><telNum>******</telNum><zipAddr>경상남도 진주시 봉래동 216 봉수동주민센터</zipAddr><zipCode>52751</zipCode></item>,
#  <item><faxNum>******</faxNum><orgCd>0276083</orgCd><orgName>(주)제이엠커리어 진주지사</orgName><orgTypeNm>수행기관</orgTypeNm><telNum>******</telNum><zipCode>52725</zipCode></item>]

# %%
rows[0]
# Out:
# <item><faxNum>******</faxNum><orgCd>0000021</orgCd><orgName>서울노인복지센터</orgName><orgTypeNm>수행기관</orgTypeNm><telNum>******</telNum><zipAddr>서울특별시 종로구 경운동 90-3</zipAddr><zipCode>03147</zipCode></item>
